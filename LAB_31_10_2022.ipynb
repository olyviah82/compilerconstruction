# %% [markdown]
# 120174 Cynthia Gichuki
# 121455 Olyviah Nyaboke
# 121759 Shamsa Abdullahi

# %% [markdown]
# ![page 2n-1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![page 3n-1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![CamScanner 11-10-2022 21.37n-1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![CamScanner 11-10-2022 21.38n-1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![CamScanner 11-10-2022 21.38(1)n-1.jpg](data:image/jpeg;base64,...)
