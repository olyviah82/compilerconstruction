# %% [markdown]
# <a href="https://colab.research.google.com/github/olyviah82/compilerconstruction/blob/main/A_LabActivity4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Lab Activity 4
121759 Shamsa Abdullahi
120174 Cynthia Gichuki 
121455 Olyviah Nyaboke

# %% [markdown]
# 1.	Using an example or illustration, explain what is predictive parsing?
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# As an extension to question 1,
# a.	What is LL (1) parsing?
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# b. Why do we get the First () and Follow () i.e. what do these two functions Really
# Represent?
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2.	Are there any unique attributes associated with Top-Down parsing?
#
#
# It accommodates ambiguity and left recursion in polynomial time.
